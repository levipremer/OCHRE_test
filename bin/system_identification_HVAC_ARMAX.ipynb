# %% [markdown]
# ## Plan
#
# This jupyter notebook breaks down the flow of using OCHRE for building
# envelope system identification

# %%
#function needed:
import pandas as pd

def attach_epw_to_df(df, epw_path,
                     keep_cols=("Dry Bulb (C)",
                                "Relative Humidity (%)",
                                "Global Horizontal Radiation (Wh/m^2)",
                                "Wind Speed (m/s)"),
                     out_names=("Temperature - Outdoor (C) [EPW]",
                                "Relative Humidity - Outdoor (%) [EPW]",
                                "Global Horizontal Irradiance (W/m^2) [EPW]",  # EPW is Wh/m² (hourly avg)
                                "Wind Speed - Outdoor (m/s) [EPW]")):
    # --- read EPW ---
    cols = [
        "Year","Month","Day","Hour","Minute","Flags",
        "Dry Bulb (C)","Dew Point (C)","Relative Humidity (%)","Atmos Pressure (Pa)",
        "Extraterrestrial Horizontal Radiation (Wh/m^2)",
        "Extraterrestrial Direct Normal Radiation (Wh/m^2)",
        "Horizontal IR Intensity (Wh/m^2)",
        "Global Horizontal Radiation (Wh/m^2)",
        "Direct Normal Radiation (Wh/m^2)",
        "Diffuse Horizontal Radiation (Wh/m^2)",
        "Global Horizontal Illuminance (lux)",
        "Direct Normal Illuminance (lux)",
        "Diffuse Horizontal Illuminance (lux)",
        "Zenith Luminance (Cd/m^2)",
        "Wind Direction (deg)","Wind Speed (m/s)","Total Sky Cover (tenths)",
        "Opaque Sky Cover (tenths)","Visibility (km)","Ceiling Height (m)",
        "Present Weather Observation","Present Weather Codes",
        "Precipitable Water (mm)","Aerosol Optical Depth (thousandths)",
        "Snow Depth (cm)","Days Since Last Snowfall",
        "Albedo","Liquid Precipitation Depth (mm)","Liquid Precipitation Quantity (hr)"
    ]
    epw = pd.read_csv(epw_path, skiprows=8, header=None, names=cols)

    # --- Build timestamp ignoring EPW 'Year' ---
    # EPW Hour = 1..24 marks END of hour → convert to start of hour
    h = epw["Hour"].to_numpy()
    carry = (h == 24).astype(int)
    hour0 = (h % 24)

    # choose a single year: the sim's year
    sim_year = int(df.index[0].year)

    dt = pd.to_datetime({
        "year": sim_year,                            # force a single year
        "month": epw["Month"],
        "day": epw["Day"],
        "hour": hour0,
        # EPW minute is usually 0 for hourly TMY; include if present
        "minute": epw["Minute"] if "Minute" in epw else 0
    })
    # shift hour=24 rows to next day (now within the same sim_year)
    dt = dt + pd.to_timedelta(carry, unit="D")

    wx = epw.set_index(dt)[list(keep_cols)].copy()
    wx.columns = list(out_names)

    # RH sanity
    if "Relative Humidity - Outdoor (%) [EPW]" in wx:
        wx["Relative Humidity - Outdoor (%) [EPW]"] = wx["Relative Humidity - Outdoor (%) [EPW]"].clip(0, 100)

    # Align to sim timeline; hourly → sub-hourly via forward-fill
    # If df has irregular start (e.g., not exactly at :00), also bfill edges.
    wx_aligned = wx.reindex(df.index, method="ffill").bfill()

    # Join
    out = df.join(wx_aligned, how="left")
    return out

# %% [markdown]
# ## Step 1
# Initialize the building and weather data. Note, how scheduling is also
# initialized, but this is for other power loads in the house (washer, dryer,
# etc.)

# %%
import os
import datetime as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from ochre import CreateFigures
from ochre import Dwelling
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
default_input_path = os.path.join(PROJECT_ROOT, "ochre", "defaults")

# %%
timestep_sim = 1 # timestep of simulation in minutes
timestep_control = 30 # in minutes
min_off_time = 600 #seconds
min_on_time = min_off_time
HP_deadband = 2  # Celsius
ER_lowerbound = 3 # celsius

# %%
dwelling_args = {
    # Timing parameters
    "start_time": dt.datetime(2018, 1, 1, 0, 0),  # (year, month, day, hour, 
    # minute)
    "time_res": dt.timedelta(minutes=timestep_sim),         # time resolution
    # of the simulation
    "duration": dt.timedelta(days=10),             # duration of the 
    # simulation to just initialize. Will change later
    "verbosity": 6,

    # Input files
    "hpxml_file": os.path.join(default_input_path, "Input Files", 
                               "bldg0112631-up11.xml"),
    "hpxml_schedule_file": os.path.join(default_input_path, "Input Files", "bldg0112631_schedule.csv"),
    "weather_file": os.path.join(default_input_path, "Weather", "USA_CO_Denver.Intl.AP.725650_TMY3.epw"),
}

# Create Dwelling model
dwelling = Dwelling(**dwelling_args)
heater = dwelling.get_equipment_by_end_use("HVAC Heating")
schedule = heater.schedule
schedule["HVAC Heating Deadband (C)"] = HP_deadband

peak_times = (schedule.index.hour >= 10) & (schedule.index.hour < 15)
schedule.loc[peak_times, "HVAC Heating Setpoint (C)"] -= 3
heater.min_on_time = min_on_time#300#600*1.5          # minimum cycle on for 
# (seconds)
heater.min_off_time = min_off_time#300#600*1.5         # minimum cycle off for (seconds)
heater.er_setpoint_offset = ER_lowerbound
heater.reset_time()

df, metrics, hourly = dwelling.simulate()
# Out:
# 2025-12-13 11:23:00.622531 - ochre at 2018-01-01 00:00:00: Initializing ochre (OCHRE v0.9.1)
# 2025-12-13 11:23:00.622897 - ochre at 2018-01-01 00:00:00: Removing previous results file: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre.csv
# 2025-12-13 11:23:00.629589 - ochre at 2018-01-01 00:00:00: Removing previous results file: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre_metrics.csv
# 2025-12-13 11:23:00.629766 - ochre at 2018-01-01 00:00:00: Removing previous results file: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre_hourly.csv
# 2025-12-13 11:23:00.630209 - ochre at 2018-01-01 00:00:00: Removing previous results file: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre_schedule.csv
# WARNING: Properties file weather station (G0800310) may be different from weather file used: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Weather/USA_CO_Denver.Intl.AP.725650_TMY3.epw
# WARNING: Cooling setpoint is within 1C of heating setpoint. Separating setpoints by at least 1C.
# 2025-12-13 11:23:02.299994 - ochre at 2018-01-01 00:00:00: Dwelling Initialized
# 2025-12-13 11:23:02.307814 - ochre at 2018-01-01 00:00:00: Running Simulation for 10 days, 0:00:00
# 2025-12-13 11:23:07.476601 - ochre at 2018-01-11 00:00:00: Simulation complete, time series results saved to: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre.csv
# 2025-12-13 11:23:07.478580 - ochre at 2018-01-11 00:00:00: Post-processing metrics saved to: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre_metrics.csv
# 2025-12-13 11:23:07.494687 - ochre at 2018-01-11 00:00:00: Hourly results saved to: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre_hourly.csv

# %%
dwelling

# %%
df.head()
# Out:
#                      Total Electric Power (kW)  Total Reactive Power (kVAR)  \
# Time
# 2018-01-01 00:00:00                    0.29796                     0.187849
# 2018-01-01 00:01:00                    0.29796                     0.187849
# 2018-01-01 00:02:00                    0.29796                     0.187849
# 2018-01-01 00:03:00                    0.29796                     0.187849
# 2018-01-01 00:04:00                    0.29796                     0.187849
#
#                      Total Gas Power (therms/hour)  \
# Time
# 2018-01-01 00:00:00                            0.0
# 2018-01-01 00:01:00                            0.0
# 2018-01-01 00:02:00                            0.0
# 2018-01-01 00:03:00                            0.0
# 2018-01-01 00:04:00                            0.0
#
#                      Total Electric Energy (kWh)  \
# Time
# 2018-01-01 00:00:00                     0.004966
# 2018-01-01 00:01:00                     0.004966
# 2018-01-01 00:02:00                     0.004966
# 2018-01-01 00:03:00                     0.004966
# 2018-01-01 00:04:00                     0.004966
#
#                      Total Reactive Energy (kVARh)  Total Gas Energy (therms)  \
# Time
# 2018-01-01 00:00:00                       0.003131                        0.0
# 2018-01-01 00:01:00                       0.003131                        0.0
# 2018-01-01 00:02:00                       0.003131                        0.0
# 2018-01-01 00:03:00                       0.003131                        0.0
# 2018-01-01 00:04:00                       0.003131                        0.0
#
#                      HVAC Heating Electric Power (kW)  \
# Time
# 2018-01-01 00:00:00                               0.0
# 2018-01-01 00:01:00                               0.0
# 2018-01-01 00:02:00                               0.0
# 2018-01-01 00:03:00                               0.0
# 2018-01-01 00:04:00                               0.0
#
#                      Lighting Electric Power (kW)  Other Electric Power (kW)  \
# Time
# 2018-01-01 00:00:00                      0.016273                   0.230687
# 2018-01-01 00:01:00                      0.016273                   0.230687
# 2018-01-01 00:02:00                      0.016273                   0.230687
# 2018-01-01 00:03:00                      0.016273                   0.230687
# 2018-01-01 00:04:00                      0.016273                   0.230687
#
#                      HVAC Cooling Electric Power (kW)  ...  \
# Time                                                   ...
# 2018-01-01 00:00:00                              0.05  ...
# 2018-01-01 00:01:00                              0.05  ...
# 2018-01-01 00:02:00                              0.05  ...
# 2018-01-01 00:03:00                              0.05  ...
# 2018-01-01 00:04:00                              0.05  ...
#
#                      Temperature - Ground (C)  \
# Time
# 2018-01-01 00:00:00                  6.529479
# 2018-01-01 00:01:00                  6.529479
# 2018-01-01 00:02:00                  6.529479
# 2018-01-01 00:03:00                  6.529479
# 2018-01-01 00:04:00                  6.529479
#
#                      Net Sensible Heat Gain - Indoor (W)  \
# Time
# 2018-01-01 00:00:00                         -3234.197179
# 2018-01-01 00:01:00                         -3210.218689
# 2018-01-01 00:02:00                         -3187.425448
# 2018-01-01 00:03:00                         -3165.139969
# 2018-01-01 00:04:00                         -3143.599224
#
#                      Net Sensible Heat Gain - Foundation (W)  \
# Time
# 2018-01-01 00:00:00                             -3157.025931
# 2018-01-01 00:01:00                             -3079.732433
# 2018-01-01 00:02:00                             -3012.066928
# 2018-01-01 00:03:00                             -2948.488956
# 2018-01-01 00:04:00                             -2888.973822
#
#                      Net Sensible Heat Gain - Garage (W)  \
# Time
# 2018-01-01 00:00:00                         -7240.811301
# 2018-01-01 00:01:00                         -7055.657737
# 2018-01-01 00:02:00                         -6887.029134
# 2018-01-01 00:03:00                         -6724.990990
# 2018-01-01 00:04:00                         -6569.929335
#
#                      Net Sensible Heat Gain - Attic (W)  \
# Time
# 2018-01-01 00:00:00                         -310.210724
# 2018-01-01 00:01:00                         -292.755506
# 2018-01-01 00:02:00                         -290.824793
# 2018-01-01 00:03:00                         -287.534525
# 2018-01-01 00:04:00                         -284.277552
#
#                      Infiltration Heat Gain - Indoor (W)  \
# Time
# 2018-01-01 00:00:00                         -3578.392666
# 2018-01-01 00:01:00                         -3560.331869
# 2018-01-01 00:02:00                         -3542.804981
# 2018-01-01 00:03:00                         -3525.788390
# 2018-01-01 00:04:00                         -3509.259999
#
#                      Forced Ventilation Heat Gain - Indoor (W)  \
# Time
# 2018-01-01 00:00:00                                       -0.0
# 2018-01-01 00:01:00                                       -0.0
# 2018-01-01 00:02:00                                       -0.0
# 2018-01-01 00:03:00                                       -0.0
# 2018-01-01 00:04:00                                       -0.0
#
#                      Natural Ventilation Heat Gain - Indoor (W)  \
# Time
# 2018-01-01 00:00:00                                        -0.0
# 2018-01-01 00:01:00                                        -0.0
# 2018-01-01 00:02:00                                        -0.0
# 2018-01-01 00:03:00                                        -0.0
# 2018-01-01 00:04:00                                        -0.0
#
#                      Internal Heat Gain - Indoor (W)  \
# Time
# 2018-01-01 00:00:00                       365.640333
# 2018-01-01 00:01:00                       365.640333
# 2018-01-01 00:02:00                       365.640333
# 2018-01-01 00:03:00                       365.640333
# 2018-01-01 00:04:00                       365.640333
#
#                      Window Transmitted Solar Gain (W)
# Time
# 2018-01-01 00:00:00                                0.0
# 2018-01-01 00:01:00                                0.0
# 2018-01-01 00:02:00                                0.0
# 2018-01-01 00:03:00                                0.0
# 2018-01-01 00:04:00                                0.0
#
# [5 rows x 50 columns]

# %%
fig = CreateFigures.plot_daily_profile(df, 'HVAC Heating Electric Power (kW)', 
                                       plot_max=False, plot_min=False)

# %%
cols_to_plot = [
    "HVAC Heating Setpoint (C)",
    "Temperature - Indoor (C)",
    "Temperature - Outdoor (C)",
    "Unmet HVAC Load (C)",
    "HVAC Heating Electric Power (kW)",
]
df.loc[:, cols_to_plot].plot()
# Out:
# <Axes: xlabel='Time'>

# %% [markdown]
# ## Create training dataset
# This portion will segment data to be trained on. This represents the "real"
# homes data.
#
# Input the number of training days you want.

# %%
train_days = 30

dwelling_args.update({
    "start_time": dt.datetime(2018, 1, 1, 0, 0),
    "duration": dt.timedelta(days=30),
    "verbosity": 9
    }
)

# Create Dwelling model
dwelling_train = Dwelling(**dwelling_args)
heater = dwelling_train.get_equipment_by_end_use("HVAC Heating")
schedule = heater.schedule
schedule["HVAC Heating Deadband (C)"] = HP_deadband

peak_times = (schedule.index.hour >= 10) & (schedule.index.hour < 15)
schedule.loc[peak_times, "HVAC Heating Setpoint (C)"] -= 3
heater.min_on_time = min_on_time
heater.min_off_time = min_off_time
heater.er_setpoint_offset = ER_lowerbound
heater.reset_time()

df_train, metrics_train, hourly_train = dwelling_train.simulate()
# Out:
# 2025-12-13 11:23:08.046689 - ochre at 2018-01-01 00:00:00: Initializing ochre (OCHRE v0.9.1)
# 2025-12-13 11:23:08.047098 - ochre at 2018-01-01 00:00:00: Removing previous results file: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre.csv
# 2025-12-13 11:23:08.051175 - ochre at 2018-01-01 00:00:00: Removing previous results file: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre_metrics.csv
# 2025-12-13 11:23:08.051300 - ochre at 2018-01-01 00:00:00: Removing previous results file: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre_hourly.csv
# WARNING: Properties file weather station (G0800310) may be different from weather file used: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Weather/USA_CO_Denver.Intl.AP.725650_TMY3.epw
# WARNING: Cooling setpoint is within 1C of heating setpoint. Separating setpoints by at least 1C.
# 2025-12-13 11:23:10.757317 - ochre at 2018-01-01 00:00:00: Saved schedule to: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre_schedule.csv
# 2025-12-13 11:23:11.123624 - ochre at 2018-01-01 00:00:00: Dwelling Initialized
# 2025-12-13 11:23:11.146126 - ochre at 2018-01-01 00:00:00: Running Simulation for 30 days, 0:00:00
# 2025-12-13 11:23:32.315964 - ochre at 2018-01-31 00:00:00: Simulation complete, time series results saved to: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre.csv
# 2025-12-13 11:23:32.320062 - ochre at 2018-01-31 00:00:00: Post-processing metrics saved to: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre_metrics.csv
# 2025-12-13 11:23:32.480243 - ochre at 2018-01-31 00:00:00: Hourly results saved to: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre_hourly.csv

# %%
df_train_with_weather = attach_epw_to_df(df_train, 
                                         dwelling_args["weather_file"])

# %%
df_train.head()
# Out:
#                      Total Electric Power (kW)  Total Reactive Power (kVAR)  \
# Time
# 2018-01-01 00:00:00                    0.29796                     0.187849
# 2018-01-01 00:01:00                    0.29796                     0.187849
# 2018-01-01 00:02:00                    0.29796                     0.187849
# 2018-01-01 00:03:00                    0.29796                     0.187849
# 2018-01-01 00:04:00                    0.29796                     0.187849
#
#                      Total Gas Power (therms/hour)  \
# Time
# 2018-01-01 00:00:00                            0.0
# 2018-01-01 00:01:00                            0.0
# 2018-01-01 00:02:00                            0.0
# 2018-01-01 00:03:00                            0.0
# 2018-01-01 00:04:00                            0.0
#
#                      Total Electric Energy (kWh)  \
# Time
# 2018-01-01 00:00:00                     0.004966
# 2018-01-01 00:01:00                     0.004966
# 2018-01-01 00:02:00                     0.004966
# 2018-01-01 00:03:00                     0.004966
# 2018-01-01 00:04:00                     0.004966
#
#                      Total Reactive Energy (kVARh)  Total Gas Energy (therms)  \
# Time
# 2018-01-01 00:00:00                       0.003131                        0.0
# 2018-01-01 00:01:00                       0.003131                        0.0
# 2018-01-01 00:02:00                       0.003131                        0.0
# 2018-01-01 00:03:00                       0.003131                        0.0
# 2018-01-01 00:04:00                       0.003131                        0.0
#
#                      HVAC Heating Electric Power (kW)  \
# Time
# 2018-01-01 00:00:00                               0.0
# 2018-01-01 00:01:00                               0.0
# 2018-01-01 00:02:00                               0.0
# 2018-01-01 00:03:00                               0.0
# 2018-01-01 00:04:00                               0.0
#
#                      Lighting Electric Power (kW)  Other Electric Power (kW)  \
# Time
# 2018-01-01 00:00:00                      0.016273                   0.230687
# 2018-01-01 00:01:00                      0.016273                   0.230687
# 2018-01-01 00:02:00                      0.016273                   0.230687
# 2018-01-01 00:03:00                      0.016273                   0.230687
# 2018-01-01 00:04:00                      0.016273                   0.230687
#
#                      HVAC Cooling Electric Power (kW)  ...  \
# Time                                                   ...
# 2018-01-01 00:00:00                              0.05  ...
# 2018-01-01 00:01:00                              0.05  ...
# 2018-01-01 00:02:00                              0.05  ...
# 2018-01-01 00:03:00                              0.05  ...
# 2018-01-01 00:04:00                              0.05  ...
#
#                      Garage Furniture Garage Film Coefficient (m^2-K/W)  \
# Time
# 2018-01-01 00:00:00                                           0.325486
# 2018-01-01 00:01:00                                           0.325486
# 2018-01-01 00:02:00                                           0.325486
# 2018-01-01 00:03:00                                           0.325486
# 2018-01-01 00:04:00                                           0.325486
#
#                      Attic Wall Attic LWR Gain (W)  \
# Time
# 2018-01-01 00:00:00                      22.309686
# 2018-01-01 00:01:00                      20.571307
# 2018-01-01 00:02:00                      20.527204
# 2018-01-01 00:03:00                      20.439605
# 2018-01-01 00:04:00                      20.227603
#
#                      Attic Wall Attic Surface Temperature (C)  \
# Time
# 2018-01-01 00:00:00                                -16.256040
# 2018-01-01 00:01:00                                -16.233508
# 2018-01-01 00:02:00                                -16.235591
# 2018-01-01 00:03:00                                -16.239104
# 2018-01-01 00:04:00                                -16.247370
#
#                      Attic Wall Attic Film Coefficient (m^2-K/W)  \
# Time
# 2018-01-01 00:00:00                                     0.325486
# 2018-01-01 00:01:00                                     0.325486
# 2018-01-01 00:02:00                                     0.325486
# 2018-01-01 00:03:00                                     0.325486
# 2018-01-01 00:04:00                                     0.325486
#
#                      Attic Roof Attic LWR Gain (W)  \
# Time
# 2018-01-01 00:00:00                     206.911467
# 2018-01-01 00:01:00                     189.203949
# 2018-01-01 00:02:00                     189.397536
# 2018-01-01 00:03:00                     187.824788
# 2018-01-01 00:04:00                     186.303508
#
#                      Attic Roof Attic Surface Temperature (C)  \
# Time
# 2018-01-01 00:00:00                                -16.386411
# 2018-01-01 00:01:00                                -16.349772
# 2018-01-01 00:02:00                                -16.353086
# 2018-01-01 00:03:00                                -16.354216
# 2018-01-01 00:04:00                                -16.362352
#
#                      Attic Roof Attic Film Coefficient (m^2-K/W)  \
# Time
# 2018-01-01 00:00:00                                     0.536264
# 2018-01-01 00:01:00                                     0.536264
# 2018-01-01 00:02:00                                     0.536264
# 2018-01-01 00:03:00                                     0.536264
# 2018-01-01 00:04:00                                     0.536264
#
#                      Attic Floor Attic LWR Gain (W)  \
# Time
# 2018-01-01 00:00:00                     -229.221153
# 2018-01-01 00:01:00                     -209.775257
# 2018-01-01 00:02:00                     -209.924739
# 2018-01-01 00:03:00                     -208.264393
# 2018-01-01 00:04:00                     -206.531110
#
#                      Attic Floor Attic Surface Temperature (C)  \
# Time
# 2018-01-01 00:00:00                                 -15.255291
# 2018-01-01 00:01:00                                 -15.314849
# 2018-01-01 00:02:00                                 -15.317247
# 2018-01-01 00:03:00                                 -15.326690
# 2018-01-01 00:04:00                                 -15.343128
#
#                     Attic Floor Attic Film Coefficient (m^2-K/W)
# Time
# 2018-01-01 00:00:00                                     0.561134
# 2018-01-01 00:01:00                                     0.561134
# 2018-01-01 00:02:00                                     0.561134
# 2018-01-01 00:03:00                                     0.561134
# 2018-01-01 00:04:00                                     0.561134
#
# [5 rows x 217 columns]

# %%
df_train_with_weather.head()
# Out:
#                      Total Electric Power (kW)  Total Reactive Power (kVAR)  \
# Time
# 2018-01-01 00:00:00                    0.29796                     0.187849
# 2018-01-01 00:01:00                    0.29796                     0.187849
# 2018-01-01 00:02:00                    0.29796                     0.187849
# 2018-01-01 00:03:00                    0.29796                     0.187849
# 2018-01-01 00:04:00                    0.29796                     0.187849
#
#                      Total Gas Power (therms/hour)  \
# Time
# 2018-01-01 00:00:00                            0.0
# 2018-01-01 00:01:00                            0.0
# 2018-01-01 00:02:00                            0.0
# 2018-01-01 00:03:00                            0.0
# 2018-01-01 00:04:00                            0.0
#
#                      Total Electric Energy (kWh)  \
# Time
# 2018-01-01 00:00:00                     0.004966
# 2018-01-01 00:01:00                     0.004966
# 2018-01-01 00:02:00                     0.004966
# 2018-01-01 00:03:00                     0.004966
# 2018-01-01 00:04:00                     0.004966
#
#                      Total Reactive Energy (kVARh)  Total Gas Energy (therms)  \
# Time
# 2018-01-01 00:00:00                       0.003131                        0.0
# 2018-01-01 00:01:00                       0.003131                        0.0
# 2018-01-01 00:02:00                       0.003131                        0.0
# 2018-01-01 00:03:00                       0.003131                        0.0
# 2018-01-01 00:04:00                       0.003131                        0.0
#
#                      HVAC Heating Electric Power (kW)  \
# Time
# 2018-01-01 00:00:00                               0.0
# 2018-01-01 00:01:00                               0.0
# 2018-01-01 00:02:00                               0.0
# 2018-01-01 00:03:00                               0.0
# 2018-01-01 00:04:00                               0.0
#
#                      Lighting Electric Power (kW)  Other Electric Power (kW)  \
# Time
# 2018-01-01 00:00:00                      0.016273                   0.230687
# 2018-01-01 00:01:00                      0.016273                   0.230687
# 2018-01-01 00:02:00                      0.016273                   0.230687
# 2018-01-01 00:03:00                      0.016273                   0.230687
# 2018-01-01 00:04:00                      0.016273                   0.230687
#
#                      HVAC Cooling Electric Power (kW)  ...  \
# Time                                                   ...
# 2018-01-01 00:00:00                              0.05  ...
# 2018-01-01 00:01:00                              0.05  ...
# 2018-01-01 00:02:00                              0.05  ...
# 2018-01-01 00:03:00                              0.05  ...
# 2018-01-01 00:04:00                              0.05  ...
#
#                      Attic Roof Attic LWR Gain (W)  \
# Time
# 2018-01-01 00:00:00                     206.911467
# 2018-01-01 00:01:00                     189.203949
# 2018-01-01 00:02:00                     189.397536
# 2018-01-01 00:03:00                     187.824788
# 2018-01-01 00:04:00                     186.303508
#
#                      Attic Roof Attic Surface Temperature (C)  \
# Time
# 2018-01-01 00:00:00                                -16.386411
# 2018-01-01 00:01:00                                -16.349772
# 2018-01-01 00:02:00                                -16.353086
# 2018-01-01 00:03:00                                -16.354216
# 2018-01-01 00:04:00                                -16.362352
#
#                      Attic Roof Attic Film Coefficient (m^2-K/W)  \
# Time
# 2018-01-01 00:00:00                                     0.536264
# 2018-01-01 00:01:00                                     0.536264
# 2018-01-01 00:02:00                                     0.536264
# 2018-01-01 00:03:00                                     0.536264
# 2018-01-01 00:04:00                                     0.536264
#
#                      Attic Floor Attic LWR Gain (W)  \
# Time
# 2018-01-01 00:00:00                     -229.221153
# 2018-01-01 00:01:00                     -209.775257
# 2018-01-01 00:02:00                     -209.924739
# 2018-01-01 00:03:00                     -208.264393
# 2018-01-01 00:04:00                     -206.531110
#
#                      Attic Floor Attic Surface Temperature (C)  \
# Time
# 2018-01-01 00:00:00                                 -15.255291
# 2018-01-01 00:01:00                                 -15.314849
# 2018-01-01 00:02:00                                 -15.317247
# 2018-01-01 00:03:00                                 -15.326690
# 2018-01-01 00:04:00                                 -15.343128
#
#                      Attic Floor Attic Film Coefficient (m^2-K/W)  \
# Time
# 2018-01-01 00:00:00                                      0.561134
# 2018-01-01 00:01:00                                      0.561134
# 2018-01-01 00:02:00                                      0.561134
# 2018-01-01 00:03:00                                      0.561134
# 2018-01-01 00:04:00                                      0.561134
#
#                      Temperature - Outdoor (C) [EPW]  \
# Time
# 2018-01-01 00:00:00                            -18.0
# 2018-01-01 00:01:00                            -18.0
# 2018-01-01 00:02:00                            -18.0
# 2018-01-01 00:03:00                            -18.0
# 2018-01-01 00:04:00                            -18.0
#
#                      Relative Humidity - Outdoor (%) [EPW]  \
# Time
# 2018-01-01 00:00:00                                   85.0
# 2018-01-01 00:01:00                                   85.0
# 2018-01-01 00:02:00                                   85.0
# 2018-01-01 00:03:00                                   85.0
# 2018-01-01 00:04:00                                   85.0
#
#                      Global Horizontal Irradiance (W/m^2) [EPW]  \
# Time
# 2018-01-01 00:00:00                                         0.0
# 2018-01-01 00:01:00                                         0.0
# 2018-01-01 00:02:00                                         0.0
# 2018-01-01 00:03:00                                         0.0
# 2018-01-01 00:04:00                                         0.0
#
#                     Wind Speed - Outdoor (m/s) [EPW]
# Time
# 2018-01-01 00:00:00                              0.0
# 2018-01-01 00:01:00                              0.0
# 2018-01-01 00:02:00                              0.0
# 2018-01-01 00:03:00                              0.0
# 2018-01-01 00:04:00                              0.0
#
# [5 rows x 221 columns]

# %% [markdown]
# Isolate the training data-set needed for envelope training.

# %%
df_envelope_train = df_train_with_weather[["HVAC Heating Electric Power (kW)", 
                              "HVAC Heating ER Power (kW)", 
                              "HVAC Heating Fan Power (kW)",
                              "HVAC Heating Delivered (W)",
                              "HVAC Heating Setpoint (C)",
                              "HVAC Cooling Setpoint (C)",
                              "HVAC Cooling Electric Power (kW)",
                              "HVAC Cooling Delivered (W)",
                              "Temperature - Indoor (C)", 
                              "Relative Humidity - Indoor (-)", 
                              "Temperature - Outdoor (C)",
                              "Temperature - Outdoor (C) [EPW]", 
                              "Global Horizontal Irradiance (W/m^2) [EPW]",
                              "Relative Humidity - Outdoor (%) [EPW]",
                              "Wind Speed - Outdoor (m/s) [EPW]"]]

# %%
df_envelope_train_1min = df_envelope_train.copy()
df_envelope_train.head()
#df_envelope_train["Temperature - Outdoor (C) [EPW]"].plot()
# Out:
#                      HVAC Heating Electric Power (kW)  \
# Time
# 2018-01-01 00:00:00                               0.0
# 2018-01-01 00:01:00                               0.0
# 2018-01-01 00:02:00                               0.0
# 2018-01-01 00:03:00                               0.0
# 2018-01-01 00:04:00                               0.0
#
#                      HVAC Heating ER Power (kW)  HVAC Heating Fan Power (kW)  \
# Time
# 2018-01-01 00:00:00                         0.0                          0.0
# 2018-01-01 00:01:00                         0.0                          0.0
# 2018-01-01 00:02:00                         0.0                          0.0
# 2018-01-01 00:03:00                         0.0                          0.0
# 2018-01-01 00:04:00                         0.0                          0.0
#
#                      HVAC Heating Delivered (W)  HVAC Heating Setpoint (C)  \
# Time
# 2018-01-01 00:00:00                         0.0                  20.611111
# 2018-01-01 00:01:00                         0.0                  20.611111
# 2018-01-01 00:02:00                         0.0                  20.611111
# 2018-01-01 00:03:00                         0.0                  20.611111
# 2018-01-01 00:04:00                         0.0                  20.611111
#
#                      HVAC Cooling Setpoint (C)  \
# Time
# 2018-01-01 00:00:00                  21.611111
# 2018-01-01 00:01:00                  21.611111
# 2018-01-01 00:02:00                  21.611111
# 2018-01-01 00:03:00                  21.611111
# 2018-01-01 00:04:00                  21.611111
#
#                      HVAC Cooling Electric Power (kW)  \
# Time
# 2018-01-01 00:00:00                              0.05
# 2018-01-01 00:01:00                              0.05
# 2018-01-01 00:02:00                              0.05
# 2018-01-01 00:03:00                              0.05
# 2018-01-01 00:04:00                              0.05
#
#                      HVAC Cooling Delivered (W)  Temperature - Indoor (C)  \
# Time
# 2018-01-01 00:00:00                         0.0                 20.293399
# 2018-01-01 00:01:00                         0.0                 20.176147
# 2018-01-01 00:02:00                         0.0                 20.062137
# 2018-01-01 00:03:00                         0.0                 19.951233
# 2018-01-01 00:04:00                         0.0                 19.843309
#
#                      Relative Humidity - Indoor (-)  \
# Time
# 2018-01-01 00:00:00                        0.045400
# 2018-01-01 00:01:00                        0.044934
# 2018-01-01 00:02:00                        0.045278
# 2018-01-01 00:03:00                        0.045616
# 2018-01-01 00:04:00                        0.045949
#
#                      Temperature - Outdoor (C)  \
# Time
# 2018-01-01 00:00:00                      -18.0
# 2018-01-01 00:01:00                      -18.0
# 2018-01-01 00:02:00                      -18.0
# 2018-01-01 00:03:00                      -18.0
# 2018-01-01 00:04:00                      -18.0
#
#                      Temperature - Outdoor (C) [EPW]  \
# Time
# 2018-01-01 00:00:00                            -18.0
# 2018-01-01 00:01:00                            -18.0
# 2018-01-01 00:02:00                            -18.0
# 2018-01-01 00:03:00                            -18.0
# 2018-01-01 00:04:00                            -18.0
#
#                      Global Horizontal Irradiance (W/m^2) [EPW]  \
# Time
# 2018-01-01 00:00:00                                         0.0
# 2018-01-01 00:01:00                                         0.0
# 2018-01-01 00:02:00                                         0.0
# 2018-01-01 00:03:00                                         0.0
# 2018-01-01 00:04:00                                         0.0
#
#                      Relative Humidity - Outdoor (%) [EPW]  \
# Time
# 2018-01-01 00:00:00                                   85.0
# 2018-01-01 00:01:00                                   85.0
# 2018-01-01 00:02:00                                   85.0
# 2018-01-01 00:03:00                                   85.0
# 2018-01-01 00:04:00                                   85.0
#
#                      Wind Speed - Outdoor (m/s) [EPW]
# Time
# 2018-01-01 00:00:00                               0.0
# 2018-01-01 00:01:00                               0.0
# 2018-01-01 00:02:00                               0.0
# 2018-01-01 00:03:00                               0.0
# 2018-01-01 00:04:00                               0.0

# %% [markdown]
# ## Training dataset is ready to use
# Training dataset is prepared. You can further exclude other variables to
# better represent the available measurements in a home. For example, it is
# unlikely to get the total heat delivered and total cooling delivered. You
# will likely only have power measurements, or indicators that the unit is on
# or off.
#
# In the training dataset, there is:
# HVAC power (including resistance heat) (kW), HVAC Heating ER Power (kW), HVAC
# Fan power (kW), HVAC Heating delivered (W), Indoor zone temperature (C), Indoor
# relative humidity (-),  Outdoor temperature (C), Outdoor relative humidity (-),
# Global horizontal irradiance (W/m^2), and Outdoor wind speed (m/s)
#
# dataframe: df_envelope_train

# %% [markdown]
# Choose what time-step you would like for training

# %%
timestep_control = 5
dt_train = timestep_control/60 #convert to hours
df_envelope_train = df_envelope_train.resample(f'{timestep_control}min').mean()

# %%
df_envelope_train_1min.head()
#df_envelope_train["Temperature - Indoor (C)"].plot()
# Out:
#                      HVAC Heating Electric Power (kW)  \
# Time
# 2018-01-01 00:00:00                               0.0
# 2018-01-01 00:01:00                               0.0
# 2018-01-01 00:02:00                               0.0
# 2018-01-01 00:03:00                               0.0
# 2018-01-01 00:04:00                               0.0
#
#                      HVAC Heating ER Power (kW)  HVAC Heating Fan Power (kW)  \
# Time
# 2018-01-01 00:00:00                         0.0                          0.0
# 2018-01-01 00:01:00                         0.0                          0.0
# 2018-01-01 00:02:00                         0.0                          0.0
# 2018-01-01 00:03:00                         0.0                          0.0
# 2018-01-01 00:04:00                         0.0                          0.0
#
#                      HVAC Heating Delivered (W)  HVAC Heating Setpoint (C)  \
# Time
# 2018-01-01 00:00:00                         0.0                  20.611111
# 2018-01-01 00:01:00                         0.0                  20.611111
# 2018-01-01 00:02:00                         0.0                  20.611111
# 2018-01-01 00:03:00                         0.0                  20.611111
# 2018-01-01 00:04:00                         0.0                  20.611111
#
#                      HVAC Cooling Setpoint (C)  \
# Time
# 2018-01-01 00:00:00                  21.611111
# 2018-01-01 00:01:00                  21.611111
# 2018-01-01 00:02:00                  21.611111
# 2018-01-01 00:03:00                  21.611111
# 2018-01-01 00:04:00                  21.611111
#
#                      HVAC Cooling Electric Power (kW)  \
# Time
# 2018-01-01 00:00:00                              0.05
# 2018-01-01 00:01:00                              0.05
# 2018-01-01 00:02:00                              0.05
# 2018-01-01 00:03:00                              0.05
# 2018-01-01 00:04:00                              0.05
#
#                      HVAC Cooling Delivered (W)  Temperature - Indoor (C)  \
# Time
# 2018-01-01 00:00:00                         0.0                 20.293399
# 2018-01-01 00:01:00                         0.0                 20.176147
# 2018-01-01 00:02:00                         0.0                 20.062137
# 2018-01-01 00:03:00                         0.0                 19.951233
# 2018-01-01 00:04:00                         0.0                 19.843309
#
#                      Relative Humidity - Indoor (-)  \
# Time
# 2018-01-01 00:00:00                        0.045400
# 2018-01-01 00:01:00                        0.044934
# 2018-01-01 00:02:00                        0.045278
# 2018-01-01 00:03:00                        0.045616
# 2018-01-01 00:04:00                        0.045949
#
#                      Temperature - Outdoor (C)  \
# Time
# 2018-01-01 00:00:00                      -18.0
# 2018-01-01 00:01:00                      -18.0
# 2018-01-01 00:02:00                      -18.0
# 2018-01-01 00:03:00                      -18.0
# 2018-01-01 00:04:00                      -18.0
#
#                      Temperature - Outdoor (C) [EPW]  \
# Time
# 2018-01-01 00:00:00                            -18.0
# 2018-01-01 00:01:00                            -18.0
# 2018-01-01 00:02:00                            -18.0
# 2018-01-01 00:03:00                            -18.0
# 2018-01-01 00:04:00                            -18.0
#
#                      Global Horizontal Irradiance (W/m^2) [EPW]  \
# Time
# 2018-01-01 00:00:00                                         0.0
# 2018-01-01 00:01:00                                         0.0
# 2018-01-01 00:02:00                                         0.0
# 2018-01-01 00:03:00                                         0.0
# 2018-01-01 00:04:00                                         0.0
#
#                      Relative Humidity - Outdoor (%) [EPW]  \
# Time
# 2018-01-01 00:00:00                                   85.0
# 2018-01-01 00:01:00                                   85.0
# 2018-01-01 00:02:00                                   85.0
# 2018-01-01 00:03:00                                   85.0
# 2018-01-01 00:04:00                                   85.0
#
#                      Wind Speed - Outdoor (m/s) [EPW]
# Time
# 2018-01-01 00:00:00                               0.0
# 2018-01-01 00:01:00                               0.0
# 2018-01-01 00:02:00                               0.0
# 2018-01-01 00:03:00                               0.0
# 2018-01-01 00:04:00                               0.0

# %%
t_end = int(48/dt_train)
#t_end = 1440
fig, ax1 = plt.subplots(figsize=(8, 4))
# Plot Indoor Temperature on the left y-axis
color1 = 'tab:blue'
ax1.plot(df_envelope_train["Temperature - Indoor (C)"].iloc[0:t_end],
         color=color1, label='Indoor Temperature (°C)')
ax1.set_xlabel('Timestep')
ax1.set_ylabel('Temperature (°C)', color=color1)
ax1.tick_params(axis='y', labelcolor=color1)

# Create a second y-axis that shares the same x-axis
ax2 = ax1.twinx()

# Plot Heating Power on the right y-axis
color2 = 'tab:red'
ax2.plot(df_envelope_train["HVAC Heating Delivered (W)"].iloc[0:t_end],
         color=color2, label='HVAC Heating Delivered (W)')
ax2.set_ylabel('Heating Power (W)', color=color2)
ax2.tick_params(axis='y', labelcolor=color2)

plt.show()

# %% [markdown]
# ## Implement Training algorithm below
#
# RC training used as an example

# %%
df_heating_annual_night = df_envelope_train.copy()
df_heating_annual_night['Hour'] = df_envelope_train.index.hour

# Define night and day conditions
# Condition 1: Time is between 10 PM and 6 AM
night_time_condition = (df_heating_annual_night['Hour'] >= 20) | \
                       (df_heating_annual_night['Hour'] < 6)

# Condition 2: Solar Irradiation is 0 (assuming 'SolarRadiation' is the correct column name)
if 'Global Horizontal Irradiance (W/m^2) [EPW]' in df_heating_annual_night.columns:
    night_solar_condition = (df_heating_annual_night['Global Horizontal Irradiance (W/m^2) [EPW]'] == 0)
    df_heating_annual_night['is_night'] = night_time_condition & night_solar_condition
else:
    print("\nWarning: 'Global Horizontal Irradiance (W/m^2) [EPW]' column not found after preprocessing. Cannot use it for night/day split.")
    df_heating_annual_night['is_night'] = night_time_condition # Fallback to just time condition

df_heating_annual_night['is_night']
# Out:
# Time
# 2018-01-01 00:00:00    True
# 2018-01-01 00:05:00    True
# 2018-01-01 00:10:00    True
# 2018-01-01 00:15:00    True
# 2018-01-01 00:20:00    True
#                        ...
# 2018-01-30 23:35:00    True
# 2018-01-30 23:40:00    True
# 2018-01-30 23:45:00    True
# 2018-01-30 23:50:00    True
# 2018-01-30 23:55:00    True
# Freq: 5min, Name: is_night, Length: 8640, dtype: bool

# %%
boolean_night = df_heating_annual_night['is_night'].astype(int)
boolean_night
# Out:
# Time
# 2018-01-01 00:00:00    1
# 2018-01-01 00:05:00    1
# 2018-01-01 00:10:00    1
# 2018-01-01 00:15:00    1
# 2018-01-01 00:20:00    1
#                       ..
# 2018-01-30 23:35:00    1
# 2018-01-30 23:40:00    1
# 2018-01-30 23:45:00    1
# 2018-01-30 23:50:00    1
# 2018-01-30 23:55:00    1
# Freq: 5min, Name: is_night, Length: 8640, dtype: int64

# %%
T_in = df_envelope_train["Temperature - Indoor (C)"].to_numpy()
Y = np.diff(T_in) / float(dt_train)  

X1 = df_envelope_train["HVAC Heating Delivered (W)"].to_numpy()[:-1] / 1000.0
X2 = (df_envelope_train["Temperature - Outdoor (C)"].to_numpy()
      - df_envelope_train["Temperature - Indoor (C)"].to_numpy())[:-1]
X3 = df_envelope_train["Global Horizontal Irradiance (W/m^2) [EPW]"].to_numpy()[:-1] / 1000.0
X4 = boolean_night.to_numpy()[:-1].astype(float)
X = np.column_stack((X1, X2, X3, X4))

# %%
'''
T_in = df_envelope_train["Temperature - Indoor (C)"].to_numpy()
Y = np.diff(T_in) / float(dt_train)  

X1 = df_envelope_train["HVAC Heating Delivered (W)"].to_numpy()[:-1] / 1000.0
X2 = (df_envelope_train["Temperature - Outdoor (C)"].to_numpy()
      - df_envelope_train["Temperature - Indoor (C)"].to_numpy())[:-1]
X3 = np.ones_like(X2)
X = np.column_stack((X1, X2, X3))
'''
# Out:
# '\nT_in = df_envelope_train["Temperature - Indoor (C)"].to_numpy()\nY = np.diff(T_in) / float(dt_train)  \n\nX1 = df_envelope_train["HVAC Heating Delivered (W)"].to_numpy()[:-1] / 1000.0\nX2 = (df_envelope_train["Temperature - Outdoor (C)"].to_numpy()\n      - df_envelope_train["Temperature - Indoor (C)"].to_numpy())[:-1]\nX3 = np.ones_like(X2)\nX = np.column_stack((X1, X2, X3))\n'

# %%
theta, residuals, rank, s = np.linalg.lstsq(X,Y)
# Out:
# /var/folders/fk/0m0g9qgs7y5fc0br86wht_1m0000gn/T/ipykernel_18900/1768169635.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   theta, residuals, rank, s = np.linalg.lstsq(X,Y)

# %%
theta
# Out:
# array([0.77300076, 0.10645143, 2.52600084, 0.11020753])

# %%
C = 1/theta[0]
R = 1/(theta[1]*C)
eta_s = C*theta[2]
w = C*theta[3]

print(f"Resistance is: {R:.4g} C/kW \n")
print(f"Capacitance is: {C:.4g} kWh/C \n")
print(f"Disturbance is: {w:.4g} kW \n")
print(f"Solar gain efficiency to indoor conditions is: {eta_s:.4g} kW per "
      f"(kW/m²)\n \n")
# Out:
# Resistance is: 7.262 C/kW
#
# Capacitance is: 1.294 kWh/C
#
# Disturbance is: 0.1426 kW
#
# Solar gain efficiency to indoor conditions is: 3.268 kW per (kW/m²)

# %% [markdown]
# ## Validation data-set for model validation

# %%
validate_days = 30

dwelling_args.update({
    "start_time": dt.datetime(2018, 2, 1, 0, 0),
    "duration": dt.timedelta(days=30),
    "verbosity": 9
    }
)
dwelling_validate = Dwelling(**dwelling_args)
heater = dwelling_validate.get_equipment_by_end_use("HVAC Heating")
schedule = heater.schedule
schedule["HVAC Heating Deadband (C)"] = HP_deadband

peak_times = (schedule.index.hour >= 10) & (schedule.index.hour < 15)
schedule.loc[peak_times, "HVAC Heating Setpoint (C)"] -= 3
heater.min_on_time = min_on_time
heater.min_off_time = min_off_time
heater.er_setpoint_offset = ER_lowerbound
heater.reset_time()

df_validate, metrics_validate, hourly_validate = dwelling_validate.simulate()
df_validate_with_weather = attach_epw_to_df(df_validate, 
                                         dwelling_args["weather_file"])
# Out:
# 2025-12-13 11:24:02.164943 - ochre at 2018-02-01 00:00:00: Initializing ochre (OCHRE v0.9.1)
# 2025-12-13 11:24:02.165307 - ochre at 2018-02-01 00:00:00: Removing previous results file: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre.csv
# 2025-12-13 11:24:02.169076 - ochre at 2018-02-01 00:00:00: Removing previous results file: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre_metrics.csv
# 2025-12-13 11:24:02.169228 - ochre at 2018-02-01 00:00:00: Removing previous results file: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre_hourly.csv
# 2025-12-13 11:24:02.169315 - ochre at 2018-02-01 00:00:00: Removing previous results file: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre_schedule.csv
# WARNING: Properties file weather station (G0800310) may be different from weather file used: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Weather/USA_CO_Denver.Intl.AP.725650_TMY3.epw
# WARNING: Cooling setpoint is within 1C of heating setpoint. Separating setpoints by at least 1C.
# 2025-12-13 11:24:05.062655 - ochre at 2018-02-01 00:00:00: Saved schedule to: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre_schedule.csv
# 2025-12-13 11:24:05.435408 - ochre at 2018-02-01 00:00:00: Dwelling Initialized
# 2025-12-13 11:24:05.459478 - ochre at 2018-02-01 00:00:00: Running Simulation for 30 days, 0:00:00
# 2025-12-13 11:24:26.960725 - ochre at 2018-03-03 00:00:00: Simulation complete, time series results saved to: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre.csv
# 2025-12-13 11:24:26.965817 - ochre at 2018-03-03 00:00:00: Post-processing metrics saved to: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre_metrics.csv
# 2025-12-13 11:24:27.555922 - ochre at 2018-03-03 00:00:00: Hourly results saved to: /Users/levipremer/PycharmProjects/OCHRE_test/ochre/defaults/Input Files/ochre_hourly.csv

# %%
df_envelope_validate = df_validate_with_weather[[
                              "HVAC Heating Electric Power (kW)", 
                              "HVAC Heating ER Power (kW)", 
                              "HVAC Heating Fan Power (kW)",
                              "HVAC Heating Delivered (W)",
                              "HVAC Heating Setpoint (C)",
                              "HVAC Cooling Setpoint (C)",
                              "HVAC Cooling Electric Power (kW)",
                              "HVAC Cooling Delivered (W)",
                              "Temperature - Indoor (C)", 
                              "Relative Humidity - Indoor (-)", 
                              "Temperature - Outdoor (C)",
                              "Temperature - Outdoor (C) [EPW]", 
                              "Global Horizontal Irradiance (W/m^2) [EPW]",
                              "Relative Humidity - Outdoor (%) [EPW]",
                              "Wind Speed - Outdoor (m/s) [EPW]"]]

df_envelope_validate = (df_envelope_validate.resample(f'{timestep_control}min')
                        .mean())

# %%
def add_is_night_column(df, ghi_col="Global Horizontal Irradiance (W/m^2) [EPW]"):
    if "Hour" not in df.columns:
        df["Hour"] = df.index.hour
    night_time_condition = (df["Hour"] >= 20) | (df["Hour"] < 6)
    if ghi_col in df.columns:
        night_solar_condition = (df[ghi_col] == 0)
        df["is_night"] = (night_time_condition & night_solar_condition).astype(float)
    else:
        # Fallback to time-only if EPW GHI is missing (keeps consistency with training fallback)
        df["is_night"] = night_time_condition.astype(float)

def simulate_Tin_forward_euler(df, theta,
                               Tin_col="Temperature - Indoor (C)",
                               Tout_col="Temperature - Outdoor (C)",
                               Qdeliv_W_col="HVAC Heating Delivered (W)",
                               ghi_col="Global Horizontal Irradiance (W/m^2) [EPW]",
                               night_col="is_night"):
    
    Tin = df[Tin_col].to_numpy(dtype=float)
    Tout = df[Tout_col].to_numpy(dtype=float)
    QkW = df[Qdeliv_W_col].to_numpy(dtype=float) / 1000.0
    GHI_kWm2 = df[ghi_col].to_numpy(dtype=float) / 1000.0
    night = df[night_col].to_numpy(dtype=float)

    dt = dt_train

    Tin_hat = np.empty_like(Tin)
    Tin_hat[0] = Tin[0]
    t0, t1, t2, t3 = theta

    for k in range(len(Tin) - 1):
        dTin_dt = t0 * QkW[k] + t1 * (Tout[k] - Tin_hat[k]) + t2 * GHI_kWm2[k] + t3 * night[k]
        Tin_hat[k + 1] = Tin_hat[k] + dt * dTin_dt

    return Tin_hat
'''
def simulate_Tin_forward_euler(df, theta, dt_hours):
    Tin = df["Temperature - Indoor (C)"].to_numpy(float)
    Tout = df["Temperature - Outdoor (C)"].to_numpy(float)
    QkW = df["HVAC Heating Delivered (W)"].fillna(0).clip(lower=0).to_numpy(float)/1000.0

    Tin_hat = np.empty_like(Tin)
    Tin_hat[0] = Tin[0]
    t0, t1, t2 = theta

    for k in range(len(Tin)-1):
        dTin_dt = t0*QkW[k] + t1*(Tout[k] - Tin_hat[k]) + t2*1.0
        Tin_hat[k+1] = Tin_hat[k] + dt_hours*dTin_dt
    return Tin_hat

'''
def rmse(y_true, y_pred):
    return float(np.sqrt(np.nanmean((y_true - y_pred) ** 2)))

def r2(y_true, y_pred):
    ss_res = float(np.nansum((y_true - y_pred) ** 2))
    ss_tot = float(np.nansum((y_true - np.nanmean(y_true)) ** 2))
    return 1.0 - ss_res / ss_tot if ss_tot > 0 else np.nan

# %%
# --- build night flags to mirror training ----------------------------------
add_is_night_column(df_envelope_train)
add_is_night_column(df_envelope_validate)

# --- simulate on train ------------------------------------------------------
Tin_train = df_envelope_train["Temperature - Indoor (C)"].to_numpy(dtype=float)
Tin_hat_train = simulate_Tin_forward_euler(
    df_envelope_train,
    theta=theta,
)
rmse_train = rmse(Tin_train, Tin_hat_train)
r2_train = r2(Tin_train, Tin_hat_train)

# --- simulate on validation (optional: long forward simulation) ------------
Tin_val = df_envelope_validate["Temperature - Indoor (C)"].to_numpy(dtype=float)
Tin_hat_val = simulate_Tin_forward_euler(
    df_envelope_validate,
    theta=theta,
)
rmse_val = rmse(Tin_val, Tin_hat_val)
r2_val = r2(Tin_val, Tin_hat_val)

# --- simulate on validation with nightly reinitialization (24h horizon) ----
# Prepare array to hold piecewise 24h predictions
Tin_hat_val_24h = np.full_like(Tin_val, np.nan, dtype=float)

dt_hours = dt_train  # assuming dt_train is in hours
steps_per_day = int(round(24.0 / dt_hours))

# Find indices corresponding to midnight within the validation set
midnight_positions = df_envelope_validate.index.indexer_at_time("00:00")

for start in midnight_positions:
    end = start + steps_per_day
    # Skip last partial day if there is not a full 24h horizon
    if end > len(df_envelope_validate):
        continue

    # Slice 24h window starting at midnight
    df_window = df_envelope_validate.iloc[start:end]

    # Use the existing simulator; this reinitializes Tin_hat[0] to measured Tin at midnight
    Tin_hat_window = simulate_Tin_forward_euler(df_window, theta=theta)

    # Store back into the big prediction array
    Tin_hat_val_24h[start:end] = Tin_hat_window

# Compute metrics using only the portions where we have predictions
rmse_val_24h = rmse(Tin_val, Tin_hat_val_24h)
r2_val_24h = r2(Tin_val, Tin_hat_val_24h)

# --- report -----------------------------------------------------------------
print(f"TRAIN RMSE: {rmse_train:.3f} °C   R²: {r2_train:.3f}")
print(f"VALIDATION (full forward) RMSE: {rmse_val:.3f} °C   R²: {r2_val:.3f}")
print(f"VALIDATION (24h reinit at midnight) RMSE: {rmse_val_24h:.3f} °C   R²: {r2_val_24h:.3f}")

# --- figure: train indoor temperature ---------------------------------
plt.figure(figsize=(11, 4.5))
plt.plot(df_envelope_train.index, Tin_train, label="Measured Tin")
plt.plot(df_envelope_train.index, Tin_hat_train, label="Model Tin (θ)", linewidth=1)
plt.xlabel("Time")
plt.ylabel("Indoor Temperature (°C)")
plt.title("Train — Indoor Temperature: Measured vs. Model")
plt.legend()
plt.tight_layout()
plt.show()

# --- figure: validation indoor temperature (24h reinit) ---------------------
plt.figure(figsize=(11, 4.5))
plt.plot(df_envelope_validate.index, Tin_val, label="Measured Tin")
plt.plot(df_envelope_validate.index, Tin_hat_val_24h,
         label="Model Tin (24h reinit)", linewidth=1)
plt.xlabel("Time")
plt.ylabel("Indoor Temperature (°C)")
plt.title("Validation — Indoor Temperature (24h Horizon, Reinitialized Nightly)")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# TRAIN RMSE: 2.010 °C   R²: -2.839
# VALIDATION (full forward) RMSE: 2.036 °C   R²: -3.284
# VALIDATION (24h reinit at midnight) RMSE: 1.557 °C   R²: -1.508

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# ------------------------- helpers ------------------------------------------
def add_is_night_column(df, ghi_col="Global Horizontal Irradiance (W/m^2) [EPW]"):
    if "Hour" not in df.columns:
        df["Hour"] = df.index.hour
    night_time_condition = (df["Hour"] >= 20) | (df["Hour"] < 6)
    if ghi_col in df.columns:
        night_solar_condition = (df[ghi_col] == 0)
        df["is_night"] = (night_time_condition & night_solar_condition).astype(float)
    else:
        df["is_night"] = night_time_condition.astype(float)

def rmse(y_true, y_pred):
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)
    return float(np.sqrt(np.nanmean((y_true - y_pred) ** 2)))

def r2(y_true, y_pred):
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)
    ss_res = float(np.nansum((y_true - y_pred) ** 2))
    ss_tot = float(np.nansum((y_true - np.nanmean(y_true)) ** 2))
    return 1.0 - ss_res / ss_tot if ss_tot > 0 else np.nan

def build_armax_arrays(df, ghi_col="Global Horizontal Irradiance (W/m^2) [EPW]"):
    """
    endog: Tin
    exog: [const, Q_deliv_kW, (Tout - Tin), GHI_kWm2, is_night]
    """
    Tin = df["Temperature - Indoor (C)"].to_numpy(dtype=float)
    Tout = df["Temperature - Outdoor (C)"].to_numpy(dtype=float)
    Qdeliv_kW = df["HVAC Heating Delivered (W)"].to_numpy(dtype=float) / 1000.0
    GHI_kWm2 = df[ghi_col].to_numpy(dtype=float) / 1000.0
    night = df["is_night"].to_numpy(dtype=float)

    exog = np.column_stack([Qdeliv_kW, (Tout - Tin), GHI_kWm2, night])
    exog = sm.add_constant(exog, has_constant="add")  # intercept

    endog = Tin
    return endog, exog

# ------------------------- build night flags --------------------------------
add_is_night_column(df_envelope_train)
add_is_night_column(df_envelope_validate)

# ------------------------- ARMAX fit ----------------------------------------
# Typical ARMAX: A(q) y = B(q) u + C(q) e
# Implemented as SARIMAX with ARMA(p,q) + exog (u)
na = 2   # AR order (p)
nc = 2   # MA order (q)

y_tr, X_tr = build_armax_arrays(df_envelope_train)

model = sm.tsa.SARIMAX(
    y_tr,
    exog=X_tr,
    order=(na, 0, nc),          # ARMA(p,q)
    trend="n",                  # we already added const in exog
    enforce_stationarity=False,
    enforce_invertibility=False,
)

res = model.fit(disp=False)
print(res.summary())

# Train predictions (in-sample, filtered)
yhat_tr = res.fittedvalues

rmse_tr = rmse(y_tr, yhat_tr)
r2_tr = r2(y_tr, yhat_tr)
print(f"TRAIN RMSE: {rmse_tr:.3f} °C   R²: {r2_tr:.3f}")

# ------------------------- Validation ---------------------------------------
y_va, X_va = build_armax_arrays(df_envelope_validate)

# (1) One-step-ahead (uses measured Tin to update state each step)
# This is the closest analog to "prediction" validation in sysID.
res_osa = res.apply(y_va, exog=X_va, refit=False)
yhat_va_osa = res_osa.fittedvalues

rmse_va_osa = rmse(y_va, yhat_va_osa)
r2_va_osa = r2(y_va, yhat_va_osa)
print(f"VALID OSA RMSE: {rmse_va_osa:.3f} °C   R²: {r2_va_osa:.3f}")

# (2) Full forward forecast (does NOT use measured Tin after the start)
fc = res.get_forecast(steps=len(y_va), exog=X_va)
yhat_va_ff = np.asarray(fc.predicted_mean)

rmse_va_ff = rmse(y_va, yhat_va_ff)
r2_va_ff = r2(y_va, yhat_va_ff)
print(f"VALID FULL-FWD RMSE: {rmse_va_ff:.3f} °C   R²: {r2_va_ff:.3f}")

# (3) 24h reinit at midnight: forecast each day starting from measured Tin at 00:00
dt_hours = float(dt_train)  # you used dt_train as hours in your earlier code
steps_per_day = int(round(24.0 / dt_hours))

yhat_va_24h = np.full_like(y_va, np.nan, dtype=float)
midnight_positions = df_envelope_validate.index.indexer_at_time("00:00")

params = res.params  # freeze trained params

for start in midnight_positions:
    end = start + steps_per_day
    if end > len(df_envelope_validate):
        continue

    # Initialize a tiny model at midnight using the measured Tin there
    y0 = np.array([y_va[start]], dtype=float)
    X0 = X_va[start:start+1, :]

    # Same ARMAX structure, same parameters
    m0 = sm.tsa.SARIMAX(
        y0,
        exog=X0,
        order=(na, 0, nc),
        trend="n",
        enforce_stationarity=False,
        enforce_invertibility=False,
    )
    r0 = m0.filter(params)

    # Forecast the remaining horizon of the day (including the first step for alignment)
    Xwin = X_va[start:end, :]
    fwin = r0.get_forecast(steps=len(Xwin), exog=Xwin).predicted_mean
    yhat_va_24h[start:end] = np.asarray(fwin)

rmse_va_24h = rmse(y_va, yhat_va_24h)
r2_va_24h = r2(y_va, yhat_va_24h)
print(f"VALID 24H-REINIT RMSE: {rmse_va_24h:.3f} °C   R²: {r2_va_24h:.3f}")

# ------------------------- Plots --------------------------------------------
plt.figure(figsize=(11, 4.5))
plt.plot(df_envelope_train.index, y_tr, label="Train Tin (measured)")
plt.plot(df_envelope_train.index, yhat_tr, label="Train Tin (ARMAX fit)", linewidth=1)
plt.xlabel("Time"); plt.ylabel("Indoor Temperature (°C)")
plt.title("Train — ARMAX (SARIMAX) fit")
plt.legend(); plt.tight_layout(); plt.show()

plt.figure(figsize=(11, 4.5))
plt.plot(df_envelope_validate.index, y_va, label="Validation Tin (measured)")
plt.plot(df_envelope_validate.index, yhat_va_osa, label="Validation (1-step-ahead)", linewidth=1)
plt.plot(df_envelope_validate.index, yhat_va_ff, label="Validation (full forward)", linewidth=1)
plt.xlabel("Time"); plt.ylabel("Indoor Temperature (°C)")
plt.title("Validation — ARMAX predictions")
plt.legend(); plt.tight_layout(); plt.show()

plt.figure(figsize=(11, 4.5))
plt.plot(df_envelope_validate.index, y_va, label="Validation Tin (measured)")
plt.plot(df_envelope_validate.index, yhat_va_24h, label="Validation (24h reinit @ midnight)", linewidth=1)
plt.xlabel("Time"); plt.ylabel("Indoor Temperature (°C)")
plt.title("Validation — ARMAX 24h reinitialized daily")
plt.legend(); plt.tight_layout(); plt.show()
# Out:
# /Users/levipremer/PycharmProjects/OCHRE_test/.venv/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 8640
# Model:               SARIMAX(2, 0, 2)   Log Likelihood                9871.118
# Date:                Sat, 13 Dec 2025   AIC                         -19722.236
# Time:                        11:24:39   BIC                         -19651.598
# Sample:                             0   HQIC                        -19698.150
#                                - 8640
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         19.7799      0.070    282.916      0.000      19.643      19.917
# x1            -0.0062      0.000    -26.645      0.000      -0.007      -0.006
# x2            -0.0058      0.001     -6.819      0.000      -0.008      -0.004
# x3             0.0383      0.020      1.925      0.054      -0.001       0.077
# x4             0.0033      0.006      0.576      0.565      -0.008       0.015
# ar.L1          1.6594      0.010    160.155      0.000       1.639       1.680
# ar.L2         -0.6835      0.010    -70.678      0.000      -0.702      -0.665
# ma.L1          0.5983      0.012     50.896      0.000       0.575       0.621
# ma.L2          0.0992      0.011      8.964      0.000       0.078       0.121
# sigma2         0.0059   6.09e-05     97.391      0.000       0.006       0.006
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):             52507.02
# Prob(Q):                              0.79   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.75   Skew:                             0.64
# Prob(H) (two-sided):                  0.00   Kurtosis:                        15.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# TRAIN RMSE: 0.077 °C   R²: 0.994
# VALID OSA RMSE: 0.074 °C   R²: 0.994
# VALID FULL-FWD RMSE: 1.022 °C   R²: -0.080
# VALID 24H-REINIT RMSE: 1.048 °C   R²: -0.136
